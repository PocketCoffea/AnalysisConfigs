# %%
import awkward as ak
import numpy as np
from matplotlib import pyplot as plt
import sys

sys.path.append('..')
from configs.jme.response_plot.pol_functions import *
from configs.jme.params.binning import eta_bins

# %%
num=10000
b = ak.Array(list(np.linspace(10, 5000, num)))

params=[        25.938393127329256,
        -7.600408839041419,
        -198.36005297300977,
        473.35093275215235,
        -512.6424968050026,
        300.9036595839161,
        -82.155039245444,
        -9.706150718617257,
        17.217544542580196,
        -7.0214465796695205,
        1.631651185453121,
        -0.24575106363103186,
        0.025391777310010053,
        -0.0018044742685164802,
        6.976460492425413e-05,]
fig, ax = plt.subplots()
# ax.plot(
#     b,
#     pol14(
#         b,
#         *params,
#     ),
# )
# remove precision from the parameters and plot after reoving each signifcant digit
for i in range(5, 20):
    params_round=[round(p, i) for p in params]
    ax.plot(
        b,
        pol14(
            b,
            *params_round,
        ),
        label=f"round {i}"
    )


ax.set_ylim(0.98, 1.05)
ax.legend()
# log scale
ax.set_xscale("log")
fig.show()

# %%
num=10000
b = ak.Array(list(np.logspace(np.log10(15), np.log10(5000), num)))

params=[        25.938393127329256,
        -7.600408839041419,
        -198.36005297300977,
        473.35093275215235,
        -512.6424968050026,
        300.9036595839161,
        -82.155039245444,
        -9.706150718617257,
        17.217544542580196,
        -7.0214465796695205,
        1.631651185453121,
        -0.24575106363103186,
        0.025391777310010053,
        -0.0018044742685164802,
        6.976460492425413e-05,0]
fig, ax = plt.subplots()

ax.plot(
    b,
    pol15(
        b,
        *params,
    ),
)


# ax.set_ylim(0.98, 1.05)
ax.legend()
# log scale
ax.set_xscale("log")
ax.grid(axis='both')
fig.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
num = 10000
b = ak.Array(list(np.logspace(np.log10(15), np.log10(4036.147), num)))

params = [
    56.97594136038965,
    -134.6968404066835,
    74.99491745966513,
    52.48032069510351,
    -36.024463136215424,
    -66.92989517212766,
    86.07892167481216,
    -32.197858967490504,
    -5.505501356750956,
    9.324747506503298,
    -3.543579869508722,
    0.5775743949197117,
    -0.002144235498229478,
    -0.01433052421202862,
    0.0020991135007209566,
    -0.00010020027322480264,
]
fig, ax = plt.subplots()

ax.plot(
    b,
    pol15(
        b,
        *params,
    ),
)


# ax.set_ylim(0.98, 1.05)
ax.legend()
# log scale
ax.set_xscale("log")
ax.grid(axis="both")
fig.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
num = 10000
b = ak.Array(list(np.logspace(np.log10(15), np.log10(4036.147), num)))

params = [
    0.4499804396951832,
    21.672187041473414,
    -46.545049230787974,
    17.284645578355498,
    32.58409385642976,
    -24.614917193658084,
    -16.541516430524876,
    27.064457045381857,
    -9.813791323549953,
    -3.120833844788636,
    4.31348549096275,
    -1.8804133117477717,
    0.45500364124810955,
    -0.06489032030794604,
    0.0051035115508598836,
    -0.0001703596426700434,
]
fig, ax = plt.subplots()

ax.plot(
    b,
    pol15(
        b,
        *params,
    ),
)


# ax.set_ylim(0.98, 1.05)
ax.legend()
# log scale
ax.set_xscale("log")
ax.grid(axis="both")
fig.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
params=[13.338564866464855  ,  -19.304973392736137   , 2.1687331528049665 ,   0.09487149435642057   , 17.730523399563882   , -14.803319050008886  ,  0.036153257269506106 ,   -2.231489598702935  ,  11.784279003523414  ,  -12.095635460913739 ,   6.262796053005872   , -1.9096308481161877  ,  0.34924984476966847   , -0.035644129670904634  ,  0.0015672923554858659 ,0]
pt= 16.38334120419252

params1=[39.115167787230355  ,  -53.98049395044786  ,  -74.18412459237345  ,  210.55784613035533  ,  -159.71156043213153  ,  18.87247150391078  ,  42.86189357986906 ,   -30.21298844218296   , 11.182763174796218  ,  -4.344497745644854 ,   2.0885133456115152   , -0.7578796021861405  ,  0.16501396239902308   , -0.01936678612414217   , 0.0009497031795979558, 0]
pt1=16.554874244062052

para_bpix=[180.78727869193077  ,  -661.4299297389515  ,  1007.3448794458942 ,   -786.7508591333382 ,   287.7280557152124  ,  7.026297560977909  ,  -45.74913349537571  ,  11.651330456231115  ,  3.0711661670356944 ,   -2.490219030153596  ,  0.6298690714669051 ,   -0.07593510387693711  ,  0.0036891932650553257, 0 ,0, 0]
pt_bpix=16.24501052846903

para_bpix1=[12.782612008929673  ,  -1.1177014071113986 ,   -20.96076313731547   , -32.159704862087814   , 76.73953259503605  ,  12.912430118179808  ,  -117.85937311068857 ,   96.31715830045911   , -11.46346232786109  ,  -30.838940529631923  ,  25.24709464463772  ,  -10.1281789017116  ,  2.4476630889660167 ,   -0.36249132164397785 ,   0.0304662531535443  ,  -0.0011175179785099117]
pt_bpix1=16.508921519315056


print(pol15(
    2278.798095703125,
    *params,
))
# Out:
# 1.026212471551844
